# %%
import pandas as pd|
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook' # force plotly to render inside the notebook

# %% [markdown]
# NYC Shelter Buildings + Repairs
# 1.which borough has the most
# 2.Which type of shelter are there more of
# 3.Which type of shelters needs the most repairs
# 4.Check for repeated repairs

# %%
df_housing = pd.read_csv("demo_2016acs5yr_nyc.csv")
df_shelter_people = pd.read_csv("DHS_Daily_Report_20260715.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_housing = pd.read_csv("demo_2016acs5yr_nyc.csv")
#       2 df_shelter_people = pd.read_csv("DHS_Daily_Report_20260715.csv ")
#
# ...

# %%
df_housing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_housing
#
# NameError: name 'df_housing' is not defined

# %%
df_shelter_people
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df_shelter_people
#
# NameError: name 'df_shelter_people' is not defined

# %%
#df = df_repairs.merge(df_shelter, on="DHS_Bld_ID")

# %%
#lets clean 
df_shelter.dtypes
#change community district to str
# Out:
# Report Date                 datetime64[ns]
# Borough                             object
# Community District                  object
# Adult Family Comm Hotel            float64
# Adult Family Shelter               float64
# Adult Shelter                      float64
# Adult Shelter Comm Hotel           float64
# FWC Cluster                        float64
# FWC Comm Hotel                     float64
# FWC Shelter                        float64
# dtype: object

# %%
df_shelter["Report Date"].unique()
# Out:
# array(['06/30/2026', '05/31/2026', '04/30/2026', '03/31/2026',
#        '02/28/2026', '01/31/2026', '12/31/2025', '11/30/2025',
#        '10/31/2025', '09/30/2025', '08/31/2025', '07/31/2025',
#        '06/30/2025', '05/31/2025', '04/30/2025', '03/31/2025',
#        '02/28/2025', '01/31/2025', '12/31/2024', '11/30/2024',
#        '10/31/2024', '09/30/2024', '08/31/2024', '07/31/2024',
#        '06/30/2024', '05/31/2024', '04/30/2024', '03/31/2024',
#        '02/29/2024', '01/31/2024', '12/31/2023', '11/30/2023',
#        '10/31/2023', '09/30/2023', '08/31/2023', '07/31/2023',
#        '06/30/2023', '05/31/2023', '04/30/2023', '03/31/2023',
#        '02/28/2023', '01/31/2023', '12/31/2022', '11/30/2022',
#        '10/31/2022', '09/30/2022', '08/31/2022', '07/31/2022',
#        '06/30/2022', '05/31/2022', '04/30/2022', '03/31/2022',
#        '02/28/2022', '01/31/2022', '12/31/2021', '11/30/2021',
#        '10/31/2021', '09/30/2021', '08/31/2021', '07/31/2021',
# ...

# %%
df_shelter["Community District"]= df_shelter["Community District"].astype(str)
df_shelter["Report Date"] = pd.to_datetime(df_shelter["Report Date"],format='%m/%d/%Y')

# %%
#checking which boro has the most shelters
shelter_loc_count = df_shelter.groupby("Borough").size().sort_values(ascending = False)
shelter_loc_count
# Out:
# Borough
# Brooklyn         1505
# Queens           1193
# Bronx            1128
# Manhattan        1103
# Staten Island     139
# Westchester        25
# dtype: int64

# %%
shelter_types = df_shelter[["Adult Family Comm Hotel", "Adult Family Shelter","Adult Shelter",                      
"Adult Shelter Comm Hotel","FWC Cluster","FWC Comm Hotel","FWC Shelter"]]

# %%
shelter_totals = shelter_types.sum()
shelter_totals
# Out:
# Adult Family Comm Hotel       239.0
# Adult Family Shelter         1418.0
# Adult Shelter               10810.0
# Adult Shelter Comm Hotel     4968.0
# FWC Cluster                  1820.0
# FWC Comm Hotel               6811.0
# FWC Shelter                 16357.0
# dtype: float64
